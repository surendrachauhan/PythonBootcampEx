# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('example_submission.csv' ,index_col=0)

# %%
df.head()
# Out:
#              alt.atheism  comp.graphics  comp.os.ms-windows.misc  \
# document_id
# 11315           0.029791       0.004623                 0.102390
# 11316           0.050539       0.043109                 0.070832
# 11317           0.100924       0.029828                 0.061425
# 11318           0.032889       0.023032                 0.092388
# 11319           0.057244       0.057136                 0.077916
#
#              comp.sys.ibm.pc.hardware  comp.sys.mac.hardware  comp.windows.x  \
# document_id
# 11315                        0.029433               0.020228        0.066824
# 11316                        0.022555               0.035361        0.050313
# 11317                        0.018137               0.065641        0.037833
# 11318                        0.062889               0.022199        0.016644
# 11319                        0.036080               0.004005        0.055557
#
#              misc.forsale  rec.autos  rec.motorcycles  rec.sport.baseball  \
# document_id
# 11315            0.079772   0.089708         0.073236            0.082225
# 11316            0.076491   0.059855         0.085492            0.011021
# 11317            0.042368   0.103079         0.055839            0.037701
# 11318            0.033153   0.049771         0.055765            0.057545
# 11319            0.037737   0.034336         0.067025            0.085071
#
#              rec.sport.hockey  sci.crypt  sci.electronics   sci.med  \
# document_id
# 11315                0.061269   0.011158         0.059382  0.033478
# 11316                0.043155   0.053429         0.059507  0.047276
# 11317                0.081018   0.040008         0.026683  0.016706
# 11318                0.040940   0.089684         0.061021  0.053585
# 11319                0.042626   0.033498         0.027101  0.011335
#
#              sci.space  soc.religion.christian  talk.politics.guns  \
# document_id
# 11315         0.032621                0.064518            0.017769
# 11316         0.043217                0.090967            0.026594
# 11317         0.104203                0.002045            0.021917
# 11318         0.039527                0.058743            0.054078
# 11319         0.046231                0.047150            0.066529
#
#              talk.politics.mideast  talk.politics.misc  talk.religion.misc
# document_id
# 11315                     0.071708            0.052148            0.017719
# 11316                     0.072508            0.023645            0.034133
# 11317                     0.000864            0.075031            0.078750
# 11318                     0.078564            0.022377            0.055207
# 11319                     0.092096            0.052141            0.069187

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(df)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scalar_feature = scaler.transform(df)

# %%
scalar_feature
# Out:
# array([[-7.07961726e-01, -1.54994629e+00,  1.80171621e+00, ...,
#          7.52399184e-01,  6.86498993e-02, -1.13875976e+00],
#        [ 1.65013720e-02, -2.13514520e-01,  7.01560004e-01, ...,
#          7.80215498e-01, -9.19039468e-01, -5.64504627e-01],
#        [ 1.77579740e+00, -6.74694224e-01,  3.73630602e-01, ...,
#         -1.70892829e+00,  8.61604010e-01,  9.96437630e-01],
#        ...,
#        [-7.60137801e-01,  1.73118679e-01, -1.62432565e+00, ...,
#         -8.00472573e-05, -1.06419995e+00, -6.87422842e-01],
#        [ 4.93823994e-01,  3.02279149e-01, -7.67654448e-01, ...,
#         -1.59420739e+00,  9.44355950e-01, -2.75659979e-01],
#        [-1.18382801e+00,  9.77665822e-02,  1.11888987e-01, ...,
#          9.74397460e-01, -1.27557728e+00, -1.50550453e-01]])

# %%
df_feat = pd.DataFrame(scalar_feature, columns=df.columns)

# %%
df_feat.head()
# Out:
#    alt.atheism  comp.graphics  comp.os.ms-windows.misc  \
# 0    -0.707962      -1.549946                 1.801716
# 1     0.016501      -0.213515                 0.701560
# 2     1.775797      -0.674694                 0.373631
# 3    -0.599811      -0.910707                 1.453036
# 4     0.250604       0.273557                 0.948509
#
#    comp.sys.ibm.pc.hardware  comp.sys.mac.hardware  comp.windows.x  \
# 0                 -0.700504              -1.040567        0.587683
# 1                 -0.937719              -0.517130        0.017145
# 2                 -1.090109               0.530243       -0.414111
# 3                  0.453348              -0.972373       -1.146314
# 4                 -0.471250              -1.601706        0.198324
#
#    misc.forsale  rec.autos  rec.motorcycles  rec.sport.baseball  \
# 0      1.016896   1.372132         0.828138            1.107710
# 1      0.904000   0.340806         1.253186           -1.361549
# 2     -0.270115   1.834051         0.224797           -0.436329
# 3     -0.587189  -0.007568         0.222232            0.251858
# 4     -0.429453  -0.540800         0.612733            1.206411
#
#    rec.sport.hockey  sci.crypt  sci.electronics   sci.med  sci.space  \
# 0          0.410731  -1.372391         0.308620 -0.578496  -0.594981
# 1         -0.224117   0.100551         0.312940 -0.096007  -0.228824
# 2          1.102920  -0.367095        -0.823594 -1.164957   1.878620
# 3         -0.301770   1.363870         0.365340  0.124582  -0.356344
# 4         -0.242651  -0.593966        -0.809091 -1.352761  -0.124662
#
#    soc.religion.christian  talk.politics.guns  talk.politics.mideast  \
# 0                0.526124           -1.108820               0.752399
# 1                1.445613           -0.804776               0.780215
# 2               -1.645767           -0.965914              -1.708928
# 3                0.325368            0.142081               0.990596
# 4               -0.077689            0.571051               1.460736
#
#    talk.politics.misc  talk.religion.misc
# 0            0.068650           -1.138760
# 1           -0.919039           -0.564505
# 2            0.861604            0.996438
# 3           -0.962976            0.172792
# 4            0.068409            0.661893

# %%
from sklearn.cross_validation import train_test_split

# %%
d = df.columns

tar = pd.DataFrame(data=d)

# %%
tar
# Out:
#                            0
# 0                alt.atheism
# 1              comp.graphics
# 2    comp.os.ms-windows.misc
# 3   comp.sys.ibm.pc.hardware
# 4      comp.sys.mac.hardware
# 5             comp.windows.x
# 6               misc.forsale
# 7                  rec.autos
# 8            rec.motorcycles
# 9         rec.sport.baseball
# 10          rec.sport.hockey
# 11                 sci.crypt
# 12           sci.electronics
# 13                   sci.med
# 14                 sci.space
# 15    soc.religion.christian
# 16        talk.politics.guns
# 17     talk.politics.mideast
# 18        talk.politics.misc
# 19        talk.religion.misc

# %%
df_feat.head()
# Out:
#    alt.atheism  comp.graphics  comp.os.ms-windows.misc  \
# 0    -0.707962      -1.549946                 1.801716
# 1     0.016501      -0.213515                 0.701560
# 2     1.775797      -0.674694                 0.373631
# 3    -0.599811      -0.910707                 1.453036
# 4     0.250604       0.273557                 0.948509
#
#    comp.sys.ibm.pc.hardware  comp.sys.mac.hardware  comp.windows.x  \
# 0                 -0.700504              -1.040567        0.587683
# 1                 -0.937719              -0.517130        0.017145
# 2                 -1.090109               0.530243       -0.414111
# 3                  0.453348              -0.972373       -1.146314
# 4                 -0.471250              -1.601706        0.198324
#
#    misc.forsale  rec.autos  rec.motorcycles  rec.sport.baseball  \
# 0      1.016896   1.372132         0.828138            1.107710
# 1      0.904000   0.340806         1.253186           -1.361549
# 2     -0.270115   1.834051         0.224797           -0.436329
# 3     -0.587189  -0.007568         0.222232            0.251858
# 4     -0.429453  -0.540800         0.612733            1.206411
#
#    rec.sport.hockey  sci.crypt  sci.electronics   sci.med  sci.space  \
# 0          0.410731  -1.372391         0.308620 -0.578496  -0.594981
# 1         -0.224117   0.100551         0.312940 -0.096007  -0.228824
# 2          1.102920  -0.367095        -0.823594 -1.164957   1.878620
# 3         -0.301770   1.363870         0.365340  0.124582  -0.356344
# 4         -0.242651  -0.593966        -0.809091 -1.352761  -0.124662
#
#    soc.religion.christian  talk.politics.guns  talk.politics.mideast  \
# 0                0.526124           -1.108820               0.752399
# 1                1.445613           -0.804776               0.780215
# 2               -1.645767           -0.965914              -1.708928
# 3                0.325368            0.142081               0.990596
# 4               -0.077689            0.571051               1.460736
#
#    talk.politics.misc  talk.religion.misc
# 0            0.068650           -1.138760
# 1           -0.919039           -0.564505
# 2            0.861604            0.996438
# 3           -0.962976            0.172792
# 4            0.068409            0.661893

# %%
X = df_feat
y = tar

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-c55e8f346529> in <module>()
# ----> 1 X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=42)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py in train_test_split(*arrays, **options)
#    2057     if test_size is None and train_size is None:
#    2058         test_size = 0.25
# -> 2059     arrays = indexable(*arrays)
#    2060     if stratify is not None:
#    2061         cv = StratifiedShuffleSplit(stratify, test_size=test_size,
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in indexable(*iterables)
#     227         else:
#     228             result.append(np.array(X))
# --> 229     check_consistent_length(*result)
#     230     return result
#     231
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     202     if len(uniques) > 1:
#     203         raise ValueError("Found input variables with inconsistent numbers of"
# --> 204                          " samples: %r" % [int(l) for l in lengths])
#     205
#     206
#
# ValueError: Found input variables with inconsistent numbers of samples: [7532, 20]
